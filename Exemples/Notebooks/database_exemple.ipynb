# %%
import pandas as pd
from sqlalchemy import create_engine, text

# %%
# Definition des paramètres de connexion à la base de données
db_username = 'postgres'
db_password = 'pass123'
db_host = '127.0.0.1'
db_port = '5432'
db_name = 'postgres'

# %%
# Création du moteur SQLAlchemy
engine = create_engine(f'postgresql+psycopg2://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}')

# %%
# Exécution d'une requête simple
sql_query = "SELECT * FROM ville"
df_villes = pd.read_sql(sql_query, engine)
df_villes
# Out:
#        ville_id ville_departement             ville_slug  \
# 0             1                01                   ozan
# 1             2                01  cormoranche-sur-saone
# 2             3                01              plagne-01
# 3             4                01                tossiat
# 4             5                01               pouillat
# ...         ...               ...                    ...
# 36695     36825               976                   sada
# 36696     36826               976               tsingoni
# 36697     36827               971          st-barthelemy
# 36698     36828               971              st-martin
# 36699     36830               975  st-pierre-et-miquelon
#
#                       ville_nom       ville_nom_simple  \
# 0                          OZAN                   ozan
# 1         CORMORANCHE-SUR-SAONE  cormoranche sur saone
# 2                        PLAGNE                 plagne
# 3                       TOSSIAT                tossiat
# 4                      POUILLAT               pouillat
# ...                         ...                    ...
# 36695                      SADA                   sada
# 36696                  TSINGONI               tsingoni
# 36697          SAINT BARTHELEMY          st barthelemy
# 36698              SAINT MARTIN              st martin
# 36699  SAINT PIERRE ET MIQUELON  st pierre et miquelon
#
#                  ville_nom_reel ville_nom_soundex ville_nom_metaphone  \
# 0                          Ozan              O250                 OSN
# 1        Cormoranche-sur-SaÃ´ne         C65652625          KRMRNXSRSN
# 2                        Plagne              P425                PLKN
# 3                       Tossiat              T230                 TST
# 4                      Pouillat              P430                 PLT
# ...                         ...               ...                 ...
# 36695                      Sada              S300                  ST
# 36696                  Tsingoni             T2525               TSNKN
# 36697         Saint-BarthÃ©lemy          S5316345            SNTPR0LM
# 36698              Saint-Martin           S535635             SNTMRTN
# 36699  Saint-Pierre-et-Miquelon        S531635245               SNTPR
#
#       ville_code_postal ville_commune  ... ville_densite_2010  ville_surface  \
# 0                 01190           284  ...                 93           6.60
# 1                 01290           123  ...                107           9.85
# 2                 01130           298  ...                 20           6.20
# 3                 01250           422  ...                138          10.17
# 4                 01250           309  ...                 14           6.23
# ...                 ...           ...  ...                ...            ...
# 36695             97640           616  ...                933          10.92
# 36696             97680           617  ...                300          34.76
# 36697             97133           123  ...                372          24.00
# 36698             97150           127  ...                695          53.20
# 36699             97500           501  ...                 25         242.00
#
#       ville_longitude_deg  ville_latitude_deg  ville_longitude_grd  \
# 0                 4.91667            46.38330                 2866
# 1                 4.83333            46.23330                 2772
# 2                 5.73333            46.18330                 3769
# 3                 5.31667            46.13330                 3309
# 4                 5.43333            46.33330                 3435
# ...                   ...                 ...                  ...
# 36695            45.10470           -12.84860                 None
# 36696            45.10700           -12.78970                 None
# 36697           -62.83330            17.91670                 None
# 36698            18.09130           -63.08290                 None
# 36699            46.71070             1.71819                 None
#
#        ville_latitude_grd  ville_longitude_dms  ville_latitude_dms  \
# 0                   51546               +45456              462330
# 1                   51379               +44953              461427
# 2                   51324               +54342              461131
# 3                   51268               +51854              460828
# 4                   51475               +52542              461938
# ...                   ...                  ...                 ...
# 36695                None                 None                None
# 36696                None                 None                None
# 36697                None                 None                None
# 36698                None                 None                None
# 36699                None                 None                None
#
#        ville_zmin  ville_zmax
# 0           170.0       205.0
# 1           168.0       211.0
# 2           560.0       922.0
# 3           244.0       501.0
# 4           333.0       770.0
# ...           ...         ...
# 36695         NaN         NaN
# 36696         NaN         NaN
# 36697         NaN         NaN
# 36698         NaN         NaN
# 36699         NaN         NaN
#
# [36700 rows x 27 columns]

# %%
# Exécution d'une requête paramètrée
departement_a_rechercher = "60"

sql_query = text("SELECT * FROM public.ville WHERE ville_departement = :departement_code")
params = {"departement_code": departement_a_rechercher}
df_villes_departement = pd.read_sql_query(sql_query, engine, params=params)
df_villes_departement
# Out:
#      ville_id ville_departement               ville_slug  \
# 0       23339                60         berneuil-en-bray
# 1       23340                60                 biermont
# 2       23341                60   abbeville-saint-lucien
# 3       23342                60            sainte-eusoye
# 4       23343                60                morienval
# ..        ...               ...                      ...
# 688     24027                60              clermont-60
# 689     24028                60        milly-sur-therain
# 690     24029                60  saint-samson-la-poterie
# 691     24030                60         ver-sur-launette
# 692     24031                60      moulin-sous-touvent
#
#                    ville_nom         ville_nom_simple  \
# 0           BERNEUIL-EN-BRAY         berneuil en bray
# 1                   BIERMONT                 biermont
# 2     ABBEVILLE-SAINT-LUCIEN   abbeville saint lucien
# 3              SAINTE-EUSOYE            sainte eusoye
# 4                  MORIENVAL                morienval
# ..                       ...                      ...
# 688                 CLERMONT                 clermont
# 689        MILLY-SUR-THERAIN        milly sur therain
# 690  SAINT-SAMSON-LA-POTERIE  saint samson la poterie
# 691         VER-SUR-LAUNETTE         ver sur launette
# 692      MOULIN-SOUS-TOUVENT      moulin sous touvent
#
#               ville_nom_reel ville_nom_soundex ville_nom_metaphone  \
# 0           Berneuil-en-Bray           B654516             BRNLNBR
# 1                   Biermont              B653               BRMNT
# 2     Abbeville-Saint-Lucien         A14253425          ABFLSNTLSN
# 3              Sainte-Eusoye              S532               SNTSY
# 4                  Morienval             M6514               MRNFL
# ..                       ...               ...                 ...
# 688                 Clermont             C4653              KLRMNT
# 689       Milly-sur-ThÃ©rain           M426365             MLSR0RN
# 690  Saint-Samson-la-Poterie       S5325254136         SNTSMSNLPTR
# 691         Ver-sur-Launette           V626453             FRSRLNT
# 692      Moulin-sous-Touvent          M4523153           MLNSSTFNT
#
#     ville_code_postal ville_commune  ... ville_densite_2010  ville_surface  \
# 0               60390           063  ...                 52          15.15
# 1               60490           071  ...                 43           3.92
# 2               60480           003  ...                100           5.26
# 3               60480           573  ...                 32           8.48
# 4               60127           430  ...                 39          25.74
# ..                ...           ...  ...                ...            ...
# 688             60600           157  ...               1819           5.81
# 689             60112           403  ...                 86          19.57
# 690             60220           596  ...                 58           4.30
# 691             60950           666  ...                 90          13.18
# 692             60350           438  ...                 12          18.14
#
#     ville_longitude_deg  ville_latitude_deg  ville_longitude_grd  \
# 0               2.06667             49.3500                 -301
# 1               2.73333             49.5833                  441
# 2               2.16667             49.5167                 -185
# 3               2.23333             49.5833                 -101
# 4               2.93333             49.3000                  648
# ..                  ...                 ...                  ...
# 688             2.40000             49.3833                   84
# 689             2.00000             49.5000                 -379
# 690             1.74195             49.5939                 -660
# 691             2.68333             49.1000                  388
# 692             3.07139             49.4564                  816
#
#      ville_latitude_grd  ville_longitude_dms  ville_latitude_dms  ville_zmin  \
# 0                 54832               +20357              492056          88
# 1                 55091               +24402              493454          63
# 2                 55019               +21011              493101         130
# 3                 55086               +21443              493437          95
# 4                 54776               +25512              491753          52
# ..                  ...                  ...                 ...         ...
# 688               54866               +22445              492244          48
# 689               55003               +15943              493009          72
# 690               55105               +14431              493538         145
# 691               54561               +24107              490618          79
# 692               54952               +30417              492723          68
#
#      ville_zmax
# 0           224
# 1            92
# 2           156
# 3           178
# 4           171
# ..          ...
# 688         162
# 689         164
# 690         214
# 691         116
# 692         158
#
# [693 rows x 27 columns]

# %%
# Affichage des 100 première lignes
df_villes_100 = df_villes.head(100)
df_villes_100
# Out:
#     ville_id ville_departement                ville_slug  \
# 0          1                01                      ozan
# 1          2                01     cormoranche-sur-saone
# 2          3                01                 plagne-01
# 3          4                01                   tossiat
# 4          5                01                  pouillat
# ..       ...               ...                       ...
# 95        96                01          petit-abergement
# 96        97                01                    cormoz
# 97        98                01     saint-martin-de-bavel
# 98        99                01  saint-trivier-de-courtes
# 99       100                01       boyeux-saint-jerome
#
#                    ville_nom          ville_nom_simple  \
# 0                       OZAN                      ozan
# 1      CORMORANCHE-SUR-SAONE     cormoranche sur saone
# 2                     PLAGNE                    plagne
# 3                    TOSSIAT                   tossiat
# 4                   POUILLAT                  pouillat
# ..                       ...                       ...
# 95       LE PETIT-ABERGEMENT       le petit abergement
# 96                    CORMOZ                    cormoz
# 97     SAINT-MARTIN-DE-BAVEL     saint martin de bavel
# 98  SAINT-TRIVIER-DE-COURTES  saint trivier de courtes
# 99       BOYEUX-SAINT-JEROME       boyeux saint jerome
#
#               ville_nom_reel ville_nom_soundex ville_nom_metaphone  \
# 0                       Ozan              O250                 OSN
# 1     Cormoranche-sur-SaÃ´ne         C65652625          KRMRNXSRSN
# 2                     Plagne              P425                PLKN
# 3                    Tossiat              T230                 TST
# 4                   Pouillat              P430                 PLT
# ..                       ...               ...                 ...
# 95       Le Petit-Abergement          L1316253          LPTTBRJMNT
# 96                    Cormoz              C652                KRMS
# 97     Saint-Martin-de-Bavel        S535635314         SNTMRTNTBFL
# 98  Saint-Trivier-de-Courtes       S5361632632        SNTTRFRTKRTS
# 99     Boyeux-Saint-JÃ©rÃ´me           B253265          BYKSSNTJRM
#
#    ville_code_postal ville_commune  ... ville_densite_2010  ville_surface  \
# 0              01190           284  ...                 93           6.60
# 1              01290           123  ...                107           9.85
# 2              01130           298  ...                 20           6.20
# 3              01250           422  ...                138          10.17
# 4              01250           309  ...                 14           6.23
# ..               ...           ...  ...                ...            ...
# 95             01260           292  ...                  5          26.95
# 96             01560           124  ...                 31          19.56
# 97             01510           372  ...                 52           8.50
# 98             01560           388  ...                 61          16.53
# 99             01640           056  ...                 18          16.94
#
#    ville_longitude_deg  ville_latitude_deg  ville_longitude_grd  \
# 0              4.91667             46.3833                 2866
# 1              4.83333             46.2333                 2772
# 2              5.73333             46.1833                 3769
# 3              5.31667             46.1333                 3309
# 4              5.43333             46.3333                 3435
# ..                 ...                 ...                  ...
# 95             5.65000             46.0333                 3697
# 96             5.23333             46.4500                 3217
# 97             5.68333             45.8500                 3712
# 98             5.08333             46.4667                 3050
# 99             5.46667             46.0333                 3467
#
#     ville_latitude_grd  ville_longitude_dms  ville_latitude_dms  ville_zmin  \
# 0                51546               +45456              462330       170.0
# 1                51379               +44953              461427       168.0
# 2                51324               +54342              461131       560.0
# 3                51268               +51854              460828       244.0
# 4                51475               +52542              461938       333.0
# ..                 ...                  ...                 ...         ...
# 95               51147               +53949              460157       706.0
# 96               51610               +51356              462657       187.0
# 97               50944               +54039              455057       249.0
# 98               51622               +50453              462735       184.0
# 99               51144               +52724              460148       329.0
#
#     ville_zmax
# 0        205.0
# 1        211.0
# 2        922.0
# 3        501.0
# 4        770.0
# ..         ...
# 95      1177.0
# 96       223.0
# 97       442.0
# 98       218.0
# 99       900.0
#
# [100 rows x 27 columns]

# %%
from datetime import datetime

def obtenir_date_heure() -> str:
    date_heure_format = "%d/%m/%Y %H:%M:%S"
    now = datetime.now()
    return now.strftime(date_heure_format)

# %%
# Sauvegarde dans Excel les 100 premières lignes
fichier_de_sauvegarde = "output_villes.xlsx"
df_villes_100.to_excel(fichier_de_sauvegarde, index=False)
print("Les données ont été sauvegardées dans le fichier", fichier_de_sauvegarde)
print("Date et heure de sauvegarde", obtenir_date_heure())
# Out:
# Les données ont été sauvegardées dans le fichier output_villes.xlsx
# Date et heure de sauvegarde 20/09/2024 16:15:24

# %%
# Sauvegarde dans une table de base de données
nom_table = "ville_output"
df_villes_departement.to_sql(nom_table, engine, if_exists='replace', index=False)
print("Les données ont été sauvegardées dans la table", nom_table)
print("Date et heure de sauvegarde", obtenir_date_heure())
# Out:
# Les données ont été sauvegardées dans la table ville_output
# Date et heure de sauvegarde 20/09/2024 16:15:49
